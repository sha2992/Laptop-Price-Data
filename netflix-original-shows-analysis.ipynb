# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/all-ended-netflix-originals/All Ended Netflix Original Shows.csv

# %%
df = pd.read_csv('/kaggle/input/all-ended-netflix-originals/All Ended Netflix Original Shows.csv')

# %%
df.head(10)
# Out:
#                      Title                            Genre  \
# 0           House of Cards                  Political drama
# 1  Orange Is the New Black                     Comedy drama
# 2               Marco Polo                 Historical drama
# 3                Bloodline                         Thriller
# 4                Daredevil             Superherolegal drama
# 5                   Sense8                  Science fiction
# 6                   Narcos                      Crime drama
# 7            Jessica Jones  Superheropsychological thriller
# 8             The Get Down                     Musicaldrama
# 9                Luke Cage      Neo-blaxploitationSuperhero
#
#         Premiere Date        Finale Date  Seasons  Cancelled
# 0    February 1, 2013   November 2, 2018        6          0
# 1       July 11, 2013      July 26, 2019        7          0
# 2   December 12, 2014       July 1, 2016        2          0
# ...

# %%
work_df = df.copy()
work_df.head()
# Out:
#                      Title                 Genre      Premiere Date  \
# 0           House of Cards       Political drama   February 1, 2013
# 1  Orange Is the New Black          Comedy drama      July 11, 2013
# 2               Marco Polo      Historical drama  December 12, 2014
# 3                Bloodline              Thriller     March 20, 2015
# 4                Daredevil  Superherolegal drama     April 10, 2015
#
#         Finale Date  Seasons  Cancelled
# 0  November 2, 2018        6          0
# 1     July 26, 2019        7          0
# 2      July 1, 2016        2          0
# 3      May 26, 2017        3          0
# 4  October 19, 2018        3          0

# %%
print('Number of columns and rows: \n',work_df.shape)
print('Number of data: \n',work_df.size)
# Out:
# Number of columns and rows:
#  (1353, 6)
# Number of data:
#  8118

# %%
work_df.describe()
# Out:
#            Seasons    Cancelled
# count  1353.000000  1353.000000
# mean      1.483370     0.722099
# std       1.036278     0.448130
# min       1.000000     0.000000
# 25%       1.000000     0.000000
# 50%       1.000000     1.000000
# 75%       2.000000     1.000000
# max       8.000000     1.000000

# %%
work_df.describe(include='all')
# Out:
#                  Title       Genre     Premiere Date        Finale Date  \
# count             1353        1240              1353               1353
# unique            1353         311               802                785
# top     House of Cards  True crime  October 28, 2022  December 17, 2021
# freq                 1          93                 7                  9
# mean               NaN         NaN               NaN                NaN
# std                NaN         NaN               NaN                NaN
# min                NaN         NaN               NaN                NaN
# 25%                NaN         NaN               NaN                NaN
# 50%                NaN         NaN               NaN                NaN
# 75%                NaN         NaN               NaN                NaN
# max                NaN         NaN               NaN                NaN
#
#             Seasons    Cancelled
# count   1353.000000  1353.000000
# unique          NaN          NaN
# ...

# %%
work_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1353 entries, 0 to 1352
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          1353 non-null   object
#  1   Genre          1240 non-null   object
#  2   Premiere Date  1353 non-null   object
#  3   Finale Date    1353 non-null   object
#  4   Seasons        1353 non-null   int64
#  5   Cancelled      1353 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 63.5+ KB

# %%
cols = work_df.columns
cols
# Out:
# Index(['Title', 'Genre', 'Premiere Date', 'Finale Date', 'Seasons',
#        'Cancelled'],
#       dtype='object')

# %%
work_df.duplicated().sum()
# Out:
# 0

# %%
work_df.isnull().sum()
# Out:
# Title              0
# Genre            113
# Premiere Date      0
# Finale Date        0
# Seasons            0
# Cancelled          0
# dtype: int64

# %%
work_df.isna().sum()
# Out:
# Title              0
# Genre            113
# Premiere Date      0
# Finale Date        0
# Seasons            0
# Cancelled          0
# dtype: int64

# %%
work_df.Genre.isnull().any()
# Out:
# True

# %%
pd.set_option('display.max_rows', None) # to see all the rows

work_df[work_df['Genre'].isnull()]
# Out:
#                                               Title Genre       Premiere Date  \
# 302                            All Hail King Julien   NaN   December 19, 2014
# 303                                 Ever After High   NaN    February 6, 2015
# 304                       Dragons: Race to the Edge   NaN       June 26, 2015
# 305                                         Popples   NaN    October 30, 2015
# 306                          Care Bears and Cousins   NaN    November 6, 2015
# 307               Lego Bionicle: The Journey to One   NaN       March 4, 2016
# 308           Lego Friends: The Power of Friendship   NaN       March 4, 2016
# 309                          Kong: King of the Apes   NaN      April 15, 2016
# 310                     Voltron: Legendary Defender   NaN       June 10, 2016
# 311                                 Justin Time GO!   NaN       June 24, 2016
# 312                                      Word Party   NaN        July 8, 2016
# ...
